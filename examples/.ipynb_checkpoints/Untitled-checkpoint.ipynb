# %%
import os
import sys
path_base = os.getcwd()+"/.."
if path_base not in sys.path:
    sys.path.append(path_base)
    print(path_base)

import shapely
import mfjet
# Out:
# /home/starlight/Workspace/mfjet/examples/..

# %%
geom = mfjet.create_dilated_points_by_disk([[10,0],[0,10]], 0.5, quad_segs=1)
geom
# Out:
# <MULTIPOLYGON (((10 -0.5, 9.5 0, 10 0.5, 10.5 0, 10 -0.5)), ((0 9.5, -0.5 10...>

# %%
geom = geom.buffer(0.5,quad_segs=1)
geom
# Out:
# <MULTIPOLYGON (((13.536 -4.036, 13.534 -4.037, 13.532 -4.039, 13.531 -4.04, ...>

# %%
geom = mfjet.create_dilated_points_by_disk([[1,0],[0,1]], 0.5, quad_segs=8)
print(isinstance(geom, shapely.Geometry))
print(isinstance(geom, shapely.Polygon))
print(isinstance(geom, shapely.MultiPolygon))
print(isinstance(geom, shapely.GeometryCollection))
print(mfjet.calc_mfs(geom))
# Out:
# True
# False
# True
# False
# [2.         6.27309698 1.56072258]

# %%
geom = mfjet.create_dilated_points([[1,0],[0,1]], 1.0)
print(isinstance(geom, shapely.Geometry))
print(isinstance(geom, shapely.Polygon))
print(isinstance(geom, shapely.MultiPolygon))
print(isinstance(geom, shapely.GeometryCollection))
print(mfjet.calc_mfs(geom))
# Out:
# True
# True
# False
# False
# [1.         9.42099347 5.70482274]

# %%
geom = mfjet.create_dilated_points([[1,0],[0,1]], 1.0)
pt = shapely.Point([3,3])
geom = shapely.ops.unary_union([geom, pt])
print(isinstance(geom, shapely.Geometry))
print(isinstance(geom, shapely.Polygon))
print(isinstance(geom, shapely.MultiPolygon))
print(isinstance(geom, shapely.GeometryCollection))
print(mfjet.calc_mfs(geom))
# Out:
# True
# False
# False
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 print(isinstance(geom, shapely.MultiPolygon))
#       7 print(isinstance(geom, shapely.GeometryCollection))
# ----> 8 print(mfjet.calc_mfs(geom))
#
# File ~/Workspace/mfjet/examples/../mfjet/minkowski_funcs.py:29, in calc_mfs(geom)
#      10 def calc_mfs(geom):
#      11     """
#      12     calculate Minkowski functionals of given geometry.
#      13
#    (...)
#      26
#      27     """
#      28     return np.array([
# ---> 29         calc_euler(geom),
#      30         calc_length(geom),
#      31         calc_area(geom),
#      32     ])
#
# File ~/Workspace/mfjet/examples/../mfjet/minkowski_funcs.py:92, in calc_euler(geom)
#      90     euler = calc_euler_poly(geom)
#      91 else:
# ---> 92     raise TypeError(f"unsupported type: {type(geom)}")
# ...

# %%
geom = mfjet.create_dilated_points([[1,0],[0,1]], 1.0)
pt = shapely.Point([3,3])
geom = shapely.ops.unary_union([geom, pt])
print(geom.boundary)
mfjet.calc_euler(geom)
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 geom = shapely.ops.unary_union([geom, pt])
#       4 print(geom.boundary)
# ----> 5 mfjet.calc_euler(geom)
#
# File ~/Workspace/mfjet/examples/../mfjet/minkowski_funcs.py:63, in calc_euler(geom)
#      61     euler = calc_euler_poly(geom)
#      62 else:
# ---> 63     raise TypeError(f"unsupported type: {type(geom)}")
#      64     #assert False, f"unsupported type: {type(geom)}"
#      65 return euler
#
# TypeError: unsupported type: <class 'shapely.geometry.collection.GeometryCollection'>

# %%
type(geom2)
# Out:
# shapely.geometry.collection.GeometryCollection

# %%
for geom in pt.boundary.geoms:
    print(1)
    print(geom)

# %%
for geom in geom2.geoms:
    print(type(geom))
# Out:
# <class 'shapely.geometry.point.Point'>
# <class 'shapely.geometry.polygon.Polygon'>

# %%
mfjet.calc_euler(1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 mfjet.calc_euler(1)
#
# File ~/Workspace/mfjet/examples/../mfjet/minkowski_funcs.py:64, in calc_euler(geom)
#      62     euler = calc_euler_poly(geom)
#      63 else:
# ---> 64     assert False, f"unsupported type: {type(geom)}"
#      65 return euler
#
# AssertionError: unsupported type: <class 'int'>

# %%
dir(mfjet.utils_shapely)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'calc_area',
#  'calc_euler',
#  'calc_euler_poly',
#  'calc_length',
#  'create_dilated_points',
#  'shapely']

# %%
mfjet.utils_shapely

# %%
dir(mfjet)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'utils_shapely',
#  'version']
